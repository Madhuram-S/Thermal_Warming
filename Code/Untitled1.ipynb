# %%
import csv
import pandas as pd
import numpy as np

# %%
tempDF = pd.read_csv("..\data\_rawdata\Temp\AverageTempCYear.csv")

# %%
tempDF.head()
# Out:
#                                     Country  Year  Jan  Feb   Mar   Apr   May  \
# 0  AFGHANISTAN                               1970  3.5  6.4   9.5  18.3  24.3
# 1  AFGHANISTAN                               1971  0.8  5.7  11.9  18.2  24.7
# 2  AFGHANISTAN                               1972  0.8 -4.2   8.2  16.4  20.7
# 3  AFGHANISTAN                               1973 -1.1  4.6  10.0  17.7  22.8
# 4  AFGHANISTAN                               1974  1.0  0.4  11.5  17.4  22.4
#
#     Jun   Jul   Aug   Sep   Oct   Nov  Dec
# 0  27.8  29.0  30.2  23.0  16.7  10.2  4.6
# 1  29.2  29.6  28.4  22.1  15.8  11.3  7.2
# 2  26.8  28.0  25.5  21.8  15.7  10.6  2.5
# 3  29.4  30.3  28.6  22.5  16.1   9.8  4.8
# 4  27.1  29.9  26.9  22.2  13.6   8.5  2.9

# %%
tempDF = tempDF.loc[tempDF['Year'] >= 1975, :]

# %%
tempDF['Country'].unique()
# Out:
# array(['AFGHANISTAN                             ',
#        'ALBANIA                                 ',
#        'ALGERIA                                 ',
#        'AMERICAN SAMOA (U.S.A.)                 ',
#        'AMSTERDAM ISLAND (FRANCE)               ',
#        'ANGOLA                                  ',
#        'ANTARCTICA                              ',
#        'ARGENTINA                               ',
#        'ARGENTINE BASE IN ANTARCTICA',
#        'ARMENIA                                 ',
#        'ASCENSION ISLAND (U.K.)                 ',
#        'AUSTRALIA                               ',
#        'AUSTRIA                                 ',
#        'AZERBAIJAN                              ',
#        'BAHRAIN                                 ',
#        'BANGLADESH                              ',
#        'BARBADOS                                ',
#        'BELARUS                                 ',
#        'BELAU                                   ',
# ...

# %%
# dummy year dataframe
yrs = pd.DataFrame({tempDF['Country'].unique(), np.arange(1975, 2018, 1)}, columns = ['Country','Year1'])
yrs.head()
# Out:
#    Year1
# 0   1975
# 1   1976
# 2   1977
# 3   1978
# 4   1979

# %%
df2 = pd.merge(tempDF, yrs, how = 'right', left_on = 'Year',right_on = 'Year1')
df2.head()
# Out:
#                                     Country  Year   Jan   Feb   Mar   Apr  \
# 0  AFGHANISTAN                               1975   1.0   2.5   9.2  15.6
# 1  ALBANIA                                   1975   4.3   5.2  10.2  12.5
# 2  ALGERIA                                   1975   8.9  10.3  12.1  16.4
# 3  AMERICAN SAMOA (U.S.A.)                   1975  26.9  27.0  27.3  26.6
# 4  AMSTERDAM ISLAND (FRANCE)                 1975  17.6  17.3  17.1  15.6
#
#     May   Jun   Jul   Aug   Sep   Oct   Nov   Dec  Year1
# 0  21.8  28.0  30.0  29.0  23.2  15.0   6.7   4.0   1975
# 1  17.4  20.4  23.0  22.4  21.1  14.6   9.6   6.4   1975
# 2  20.7  23.8  28.5  27.8  24.7  18.9  12.8  10.9   1975
# 3  26.7  26.2  26.3  26.3  26.4  27.3  26.8  26.3   1975
# 4  14.2  11.3  11.7  10.5  11.4  12.6  14.5  16.4   1975

# %%
df2[['Year','Year1']].isnull().values.sum()
# Out:
# 0
